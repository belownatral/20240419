# %% [markdown]
# <a href="https://colab.research.google.com/github/belownatral/20240419/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# varible inspector may impact runtime performance while open

# %% [markdown]
# ## basic data types
# * inf
# * float
# * bool
# * str

# %%
abc = 1

# %%
_xyz = 2

# %%
abc
# Out:
# 1

# %% [markdown]
# Use type(with varibe name) Cheak want the type of the varible you are using.

# %%
x = 1

# %%
type(x)
# Out:
# int

# %%
y = 2

# %%
y = 3.12

# %%
type(y)
# Out:
# float

# %%
2 == 3> 2
# Out:
# False

# %%
2>3
# Out:
# False

# %%
2 == 2>3
# Out:
# False

# %%
s = "dog"

# %%
type(s)
# Out:
# str

# %% [markdown]
# ## Common math operators

# %% [markdown]
# ## add, subract, mutipucation, divistion

# %%
3 + 2
# Out:
# 5

# %%
3 - 2
# Out:
# 1

# %%
69 * 2
# Out:
# 138

# %%
65 // 2
# Out:
# 32

# %%
2 >= 2
# Out:
# True

# %%
if False

# %% [markdown]
# input 3
# write a code use input() add a number

# %%
x = input ("nuber varible")
if True:
  print("number bigger than 10")
else:
  print("number smaller than 10")
# Out:
# nuber varible9
# number bigger than 10

# %%
import random
import random

n = random.randint(1, 5)
x = int(input("Enter a number: "))

if True:
  print("u are right! answer is n")
else:
    print("u r wrong LL ez kid image! the anwer is n")
# Out:
# Enter a number: 3
# u are right! answer is n

# %% [markdown]
# second big topic
# ### read a image

# %%
from PIL import Image

# %%
img = Image.open("eeeee.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %% [markdown]
# change color to only one

# %%
img.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=1024x1024>

# %% [markdown]
# img resize

# %%
img.size
# Out:
# (1024, 1024)

# %%
img.resize("1200//4, 1200//4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-3884c57d880d> in <cell line: 1>()
# ----> 1 img.resize("1200//4, 1200//4")
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    2190                 )
#    2191
# -> 2192         return self._new(self.im.resize(size, resample, box))
#    2193
#    2194     def reduce(self, factor, box=None):
#
# TypeError: argument 1 must be sequence of length 2, not 16

# %%
img01 = img.copy()

# %%
img01.thumbnail?

# %%
img01.thumbnail((200,200))

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
img01.transpose?

# %%
img01.transpose(Image.Transpose.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
r, g, b=img.split()
Image.merge('RGB', (b, g, r))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
img01.crop((50, 0, 150, 100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img01.paste(img01,(50, 0, 150, 100))
img01
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-c7852088c9c3> in <cell line: 1>()
# ----> 1 img01.paste(img01,(50, 0, 150, 100))
#       2 img01
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in paste(self, im, box, mask)
#    1731             self.im.paste(im, box, mask.im)
#    1732         else:
# -> 1733             self.im.paste(im, box)
#    1734
#    1735     def alpha_composite(self, im, dest=(0, 0), source=(0, 0)):
#
# ValueError: images do not match

# %%
img01 = Image.new("RGB", (400, 146),"black")

# %%
img.paste(img, (0, 0))

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGB size=400x146>
